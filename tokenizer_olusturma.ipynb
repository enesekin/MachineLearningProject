# %%
import tensorflow
import pandas as pd
import numpy as np
from tensorflow.compat.v1.keras.preprocessing.text import Tokenizer

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
dataframe = pd.read_csv('/content/gdrive/MyDrive/MachineLearningProject/amazon_reviews_us_son2.csv', sep = ",")
dataframe['reviews.text'] = dataframe['reviews.text'].astype(str)
data = dataframe['reviews.text'].values.tolist()

# %%
type(target)
# Out:
# list

# %%
data[120]
# Out:
# 'its the best way to watch tv and movies it has everything you need'

# %%
tokenizer = Tokenizer(num_words=None, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=' ', char_level=False, oov_token=None, document_count=0)

# %%
tokenizer.fit_on_texts(data)

# %%
from itertools import islice

def take(n, iterable):
    "Return first n items of the iterable as a list"
    return islice(iterable, n)

# %%
type(tokenizer.word_index.items())
# Out:
# dict_items

# %%
n_items = take(10000, tokenizer.word_index.items())

# %%
print(str(dict(n_items)))
# Out:
# {'the': 1, 'and': 2, 'to': 3, 'i': 4, 'it': 5, 'for': 6, 'a': 7, 'is': 8, 'my': 9, 'this': 10, 'great': 11, 'of': 12, 'with': 13, 'on': 14, 'tablet': 15, 'love': 16, 'have': 17, 'use': 18, 'you': 19, 'in': 20, 'easy': 21, 'that': 22, 'was': 23, 'so': 24, 'as': 25, 'very': 26, 'kindle': 27, 'can': 28, 'amazon': 29, 'one': 30, 'bought': 31, 'but': 32, 'fire': 33, 'all': 34, 'she': 35, 'not': 36, 'has': 37, 'good': 38, 'price': 39, 'we': 40, 'product': 41, 'tv': 42, "it's": 43, 'up': 44, 'an': 45, 'are': 46, 'more': 47, 'like': 48, 'echo': 49, 'works': 50, 'loves': 51, 'just': 52, 'read': 53, 'would': 54, 'much': 55, 'at': 56, 'or': 57, 'music': 58, 'had': 59, 'be': 60, 'get': 61, 'alexa': 62, 'best': 63, 'they': 64, 'books': 65, 'from': 66, 'if': 67, 'reading': 68, 'than': 69, 'well': 70, 'buy': 71, 'her': 72, 'device': 73, 'kids': 74, 'me': 75, 'do': 76, 'really': 77, 'purchased': 78, 'also': 79, 'when': 80, 'no': 81, 'recommend': 82, 'time': 83, 'old': 84, 'apps': 85, 'games': 86, 'h
# ...

# %%
import pickle

with open("/content/gdrive/MyDrive/MachineLearningProject/tokenizer.pickle", "wb") as handle:
  pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
